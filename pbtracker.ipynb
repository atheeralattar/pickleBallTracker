# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv8n model
model = YOLO("yolov10n.pt")

# Display model information (optional)
model.info()

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="coco8.yaml", epochs=100, imgsz=640)

# Run inference with the YOLOv8n model on the 'bus.jpg' image
# Out:
# YOLOv10n summary: 385 layers, 2,775,520 parameters, 0 gradients, 8.7 GFLOPs
# Ultralytics 8.3.34 🚀 Python-3.12.2 torch-2.5.1+cu124 CPU (Intel Xeon E5-2660 v3 2.60GHz)
# ...

# %%
import cv2

# %%
results = model("image.png")
# Out:
# image 1/1 /home/atheer/Documents/pickleBallTracker/image.png: 448x640 5 persons, 1 car, 1 bus, 1 truck, 3 traffic lights, 74.1ms
# Speed: 3.2ms preprocess, 74.1ms inference, 2.2ms postprocess per image at shape (1, 3, 448, 640)

# %%
# Path to the input video
video_path = 'vid.mp4'

# Open the video file
cap = cv2.VideoCapture(video_path)

# Get video properties
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Output video writer
out = cv2.VideoWriter('output_tracked_video11.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps, (frame_width, frame_height))

# Define target class (e.g., "sports ball")
TARGET_CLASS = 'sports ball'  # Change if another class represents the pickleball

# Loop through video frames
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Run YOLO model on the frame
    results = model(frame)

    # Draw bounding boxes and labels for the target class
    for result in results:
        for box in result.boxes:  # Each detected box
            cls = int(box.cls[0])  # Get the class index
            label = model.names[cls]  # Get the class name

            if label == TARGET_CLASS:  # Check if it matches the target class
                x1, y1, x2, y2 = map(int, box.xyxy[0])  # Get box coordinates
                confidence = box.conf[0]  # Confidence score
                label_text = f"{label} {confidence:.2f}"

                # Draw the bounding box
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                # Put the label
                cv2.putText(frame, label_text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

    # Write the frame to the output video
    out.write(frame)

    # Display the frame (optional)
    # cv2.imshow('Tracking', frame)
    # if cv2.waitKey(1) & 0xFF == ord('q'):
    #     break

# Release resources
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 (no detections), 67.0ms
# Speed: 1.4ms preprocess, 67.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.8ms
# Speed: 1.3ms preprocess, 57.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.7ms
# Speed: 1.2ms preprocess, 56.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.6ms
# Speed: 1.2ms preprocess, 56.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.2ms
# Speed: 1.3ms preprocess, 57.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.9ms
# Speed: 1.3ms preprocess, 59.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 56.8ms
# Speed: 1.5ms preprocess, 56.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 57.2ms
# ...
